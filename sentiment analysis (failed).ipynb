# %%
import pandas as pd

# %%
df= pd.read_excel ('./pos vs neg 柱状.xlsx')

# %%
df
# Out:
#                              Attributes  Amount
# 0  Total number of negative words\n\n\n    1549
# 1        Total number of positive words    1893

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

# %%
bar=(
    Bar()
    .add_xaxis(df['Attributes'].to_list())
    .add_yaxis('Amount',df['Amount'].to_list())
    .set_global_opts(title_opts=opts.TitleOpts(title='pos vs neg'))
)

# %%
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="61bdcac2be7c46d18246794210324a72" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_61bdcac2be7c46d18246794210324a72 = echarts.init(
#                     document.getElementById('61bdcac2be7c46d18246794210324a72'), 'white', {renderer: 'canvas'});
#                 var option_61bdcac2be7c46d18246794210324a72 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie

# %%
def create_pie(datas, title) -> Pie:
    pie = Pie()
    pie.add("", datas)
    pie.set_global_opts(
        title_opts=opts.TitleOpts(title=title),
        legend_opts=opts.LegendOpts(pos_right="right")
    )
    pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}: {d}%"))
    return pie

# %%
import pandas as pd

# %%
df = pd.read_excel("./pos vs neg 饼图.xlsx")

# %%
df
# Out:
#        Attributes  Percentage
# 0  negative words      0.0245
# 1         neutral      0.9456
# 2  positive words      0.0299

# %%
x_data= df['Attributes'].tolist()
x_data
# Out:
# ['negative words', 'neutral', 'positive words']

# %%
y_data=df['Percentage'].tolist()
y_data
# Out:
# [0.0245, 0.9456, 0.0299]

# %%
pie = (
    Pie()
    .add("", [list(z) for z in zip(x_data, y_data)])   
    .set_global_opts(title_opts=opts.TitleOpts(title="pos vs neg"))  
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))  
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4084d7aa1fde4fe29d1693ab68055f28" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4084d7aa1fde4fe29d1693ab68055f28 = echarts.init(
#                     document.getElementById('4084d7aa1fde4fe29d1693ab68055f28'), 'white', {renderer: 'canvas'});
#                 var option_4084d7aa1fde4fe29d1693ab68055f28 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
